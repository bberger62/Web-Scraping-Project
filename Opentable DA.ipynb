# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('opentable_scrape1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-67430ac9a4a9> in <module>
# ----> 1 df = pd.read_csv('opentable_scrape1.csv')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'opentable_scrape1.csv' does not exist: b'opentable_scrape1.csv'

# %%
df.rating_list
# Out:
# 0       4.5 stars out of 5
# 1       4.6 stars out of 5
# 2       4.5 stars out of 5
# 3       4.6 stars out of 5
# 4       4.4 stars out of 5
#                ...
# 1257    4.6 stars out of 5
# 1258    4.3 stars out of 5
# 1259    4.7 stars out of 5
# 1260    4.7 stars out of 5
# 1261    4.6 stars out of 5
# Name: rating_list, Length: 1262, dtype: object

# %%
float(df.rating_list[0][:4])
# Out:
# 4.5

# %%
df.head()
# Out:
#    booked_today_list  delivery          expensive     genre  \
# 0                NaN  Delivery       $    $           Greek
# 1                NaN  Delivery       $    $        American
# 2                NaN  Delivery       $    $         Mexican
# 3                NaN  Delivery       $    $         Seafood
# 4                NaN  Delivery    $    $    $       Italian
#
#             location num_reviews_list         rating_list  \
# 0       Midtown West            (943)  4.5 stars out of 5
# 1    Upper West Side             (93)  4.6 stars out of 5
# 2     Hell's Kitchen           (1005)  4.5 stars out of 5
# 3            Chelsea            (473)  4.6 stars out of 5
# 4  Greenwich Village            (519)  4.4 stars out of 5
#
#                rest_name
# 0    Souvlaki GR Midtown
# 1            Trump Grill
# 2  Tacuba Hell's Kitchen
# 3        Cull and Pistol
# 4               Gradisca

# %%
df['num_reviews_list'].str.replace('(','')
# Out:
# 0      312)
# 1       26)
# 2       94)
# 3      129)
# 4       84)
# 5      102)
# 6      752)
# 7     5270)
# 8     1643)
# 9       NaN
# 10     104)
# 11      35)
# 12     278)
# 13     570)
# 14     548)
# 15      30)
# 16      NaN
# 17     256)
# 18    1455)
# 19    1517)
# 20      30)
# 21    4255)
# Name: num_reviews_list, dtype: object

# %%
df.expensive[0].count('$')
# Out:
# 2

# %%
x = 8



if x <10:
    print('Swag')
else: print('lame')
# Out:
# Swag

# %%
df['expensive'] = df['expensive'].apply(lambda x: x.count('$'))

# %%
df['num_reviews_list'] = df['num_reviews_list'].str.replace('(','')

# %%
df['num_reviews_list'] = df['num_reviews_list'].str.replace(')','')

# %%
int(df['num_reviews_list'][0])
# Out:
# 943

# %%
df
# Out:
#     booked_today_list            delivery  expensive           genre  \
# 0                 NaN             Takeout          4      Steakhouse
# 1                 NaN                   2          3         Italian
# 2                 NaN             Takeout          3          French
# 3                 NaN                   2          2      Vietnamese
# 4                 NaN                   2          3  Latin American
# 5                 NaN             Takeout          2         Seafood
# 6                 NaN             Takeout          3   Mediterranean
# 7                 NaN                   2          2         Italian
# 8                 NaN             Takeout          2          French
# 9                 NaN   Delivery partners          2         Chinese
# 10                NaN                   2          2         Chinese
# 11                NaN                   2          4         Italian
# 12                NaN             Takeout          2         Italian
# 13                NaN             Takeout          2         Italian
# 14                NaN   Delivery partners          2         Italian
# 15                NaN                   2          2        American
# 16                NaN                   2          4           Sushi
# 17                NaN   Delivery partners          2         Italian
# 18                NaN   Delivery partners          2         Italian
# 19                NaN             Takeout          2          Indian
# 20                NaN             Takeout          2         Mexican
# 21                NaN                   2          3      Steakhouse
#
#                               location num_reviews_list         rating_list  \
# 0                         Union Square              312  4.4 stars out of 5
# 1                         Little Italy               26  4.5 stars out of 5
# 2                   TriBeCa - Downtown               94  4.5 stars out of 5
# 3                               NoLita              129  4.4 stars out of 5
# 4                      Upper East Side               84  4.7 stars out of 5
# 5                         Battery Park              102  4.3 stars out of 5
# 6                                 SoHo              752  4.4 stars out of 5
# 7                    Greenwich Village             5270  4.6 stars out of 5
# 8                                 SoHo             1643  4.3 stars out of 5
# 9   Garment District / Flower District              NaN                 NaN
# 10                        Midtown West              104  4.1 stars out of 5
# 11                        West Village               35  4.5 stars out of 5
# 12                                NoHo              278  4.4 stars out of 5
# 13                        East Village              570  4.6 stars out of 5
# 14                      Hell's Kitchen              548  4.7 stars out of 5
# 15                      Hell's Kitchen               30  3.6 stars out of 5
# 16                     Columbus Circle              NaN                 NaN
# 17                        Midtown East              256  4.2 stars out of 5
# 18                        Midtown West             1455  4.6 stars out of 5
# 19     Theater District / Times Square             1517  4.3 stars out of 5
# 20     Theater District / Times Square               30  4.5 stars out of 5
# 21                        Midtown West             4255  4.3 stars out of 5
#
#                             rest_name
# 0               Strip House Speakeasy
# 1              Zia Maria Little Italy
# 2                                Yves
# 3                             BoCaphe
# 4             Dulce Vida Latin Bistro
# 5                             Miramar
# 6                           Pera Soho
# 7                                Lupa
# 8                        Laduree SOHO
# 9                       Shanghai Mong
# 10                          Red Peony
# 11                     Piccolo Angolo
# 12                          Misirizzi
# 13                            Porsena
# 14                               kilo
# 15           Sall Restaurant & Lounge
# 16      Blue Ribbon Sushi Bar & Grill
# 17  Angelo Bellini Italian Restaurant
# 18                           PizzArte
# 19         Utsav Indian Bar and Grill
# 20                      Tito Murphy's
# 21                STK - NYC - Midtown

# %%
df['num_reviews_list'] = df['num_reviews_list'].apply(lambda x: int(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-78988bf0e92f> in <module>
# ----> 1 df['num_reviews_list'] = df['num_reviews_list'].apply(lambda x: int(x))
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-24-78988bf0e92f> in <lambda>(x)
# ----> 1 df['num_reviews_list'] = df['num_reviews_list'].apply(lambda x: int(x))
#
# ValueError: cannot convert float NaN to integer

# %%
df
# Out:
#       booked_today_list  delivery  expensive                 genre  \
# 0                   NaN  Delivery          2                 Greek
# 1                   NaN  Delivery          2              American
# 2                   NaN  Delivery          2               Mexican
# 3                   NaN  Delivery          2               Seafood
# 4                   NaN  Delivery          3               Italian
# ...                 ...       ...        ...                   ...
# 1257                NaN  Delivery          3  Contemporary Italian
# 1258                NaN  Delivery          2               Italian
# 1259                NaN  Delivery          3               Italian
# 1260                NaN  Delivery          2              American
# 1261                NaN  Delivery          3                Indian
#
#                              location  num_reviews_list         rating_list  \
# 0                        Midtown West                 2  4.5 stars out of 5
# 1                     Upper West Side                 2  4.6 stars out of 5
# 2                      Hell's Kitchen                 2  4.5 stars out of 5
# 3                             Chelsea                 2  4.6 stars out of 5
# 4                   Greenwich Village                 3  4.4 stars out of 5
# ...                               ...               ...                 ...
# 1257                     East Village                 3  4.6 stars out of 5
# 1258  Theater District / Times Square                 2  4.3 stars out of 5
# 1259  Theater District / Times Square                 3  4.7 stars out of 5
# 1260                          Chelsea                 2  4.7 stars out of 5
# 1261                     Midtown East                 3  4.6 stars out of 5
#
#                     rest_name
# 0         Souvlaki GR Midtown
# 1                 Trump Grill
# 2       Tacuba Hell's Kitchen
# 3             Cull and Pistol
# 4                    Gradisca
# ...                       ...
# 1257             Cacio e Pepe
# 1258  Ceci Italian Restaurant
# 1259              La Masseria
# 1260      Westville - Chelsea
# 1261                     Amma
#
# [1262 rows x 8 columns]
